# %%
import pandas as pd

# %%
employees = pd.read_csv('~/user_audit/data/employees.csv')
employees
# Out:
#     employee_number  first_name   last_name  \
# 0         EMP003037     Juliana    Burbudge
# 1         EMP003045      Lizzie        Blue
# 2         EMP003051     Marjory    Selcraig
# 3         EMP003068      Aguste    O'Connor
# 4         EMP003097     Clemens      Kopman
# ..              ...         ...         ...
# 970       EMP024864    Kristina       Yakov
# 971       EMP024885   Margarita  Habbergham
# 972       EMP024890    Prescott   Southward
# 973       EMP024896       Raine     Learned
# 974       EMP024931  Frederique        Fant
#
#                                     email              title
# 0        juliana.burbudge@consultants.com  Director of Sales
# 1             lizzie.blue@consultants.com    Sales Assistant
# 2        marjory.selcraig@consultants.com    Sales Assistant
# 3         aguste.o'connor@consultants.com    Sales Assistant
# 4          clemens.kopman@consultants.com    Account Manager
# ..                                    ...                ...
# ...

# %%
system_access = pd.read_csv('~/user_audit/data/system_access.csv')
system_access
# Out:
#         id    access_level
# 0     3045  Contract Entry
# 1     3051  Contract Entry
# 2     3068  Contract Entry
# 3     3097   Account Admin
# 4     3133  Contract Entry
# ..     ...             ...
# 833  24862  Contract Entry
# 834  24864  Contract Entry
# 835  24885   Account Admin
# 836  24890  Contract Entry
# 837  24896   Account Admin
#
# [838 rows x 2 columns]

# %%
system_access1 = system_access.drop(['id'],axis=1)
system_access1
# Out:
#        access_level
# 0    Contract Entry
# 1    Contract Entry
# 2    Contract Entry
# 3     Account Admin
# 4    Contract Entry
# ..              ...
# 833  Contract Entry
# 834  Contract Entry
# 835   Account Admin
# 836  Contract Entry
# 837   Account Admin
#
# [838 rows x 1 columns]

# %%
result = pd.concat([system_access1,employees],sort = False)
result
# Out:
#        access_level employee_number  first_name   last_name  \
# 0    Contract Entry             NaN         NaN         NaN
# 1    Contract Entry             NaN         NaN         NaN
# 2    Contract Entry             NaN         NaN         NaN
# 3     Account Admin             NaN         NaN         NaN
# 4    Contract Entry             NaN         NaN         NaN
# ..              ...             ...         ...         ...
# 970             NaN       EMP024864    Kristina       Yakov
# 971             NaN       EMP024885   Margarita  Habbergham
# 972             NaN       EMP024890    Prescott   Southward
# 973             NaN       EMP024896       Raine     Learned
# 974             NaN       EMP024931  Frederique        Fant
#
#                                     email            title
# 0                                     NaN              NaN
# 1                                     NaN              NaN
# 2                                     NaN              NaN
# ...

# %%
merged = pd.merge(employees, system_access, how='outer',
                  left_on='employee_number', right_on='access_level')
merged = merged.drop('id', 1) # drop duplicate info
merged.head()
# Out:
#   employee_number first_name last_name                             email  \
# 0       EMP003037    Juliana  Burbudge  juliana.burbudge@consultants.com
# 1       EMP003045     Lizzie      Blue       lizzie.blue@consultants.com
# 2       EMP003051    Marjory  Selcraig  marjory.selcraig@consultants.com
# 3       EMP003068     Aguste  O'Connor   aguste.o'connor@consultants.com
# 4       EMP003097    Clemens    Kopman    clemens.kopman@consultants.com
#
#                title access_level
# 0  Director of Sales          NaN
# 1    Sales Assistant          NaN
# 2    Sales Assistant          NaN
# 3    Sales Assistant          NaN
# 4    Account Manager          NaN

# %%
#pip install openpyxl
import pandas as pd
#reading the csv files
employee = pd.read_excel(r'attachment_1.xlsx', sheet_name = 'employees', header=0)
sys_access = pd.read_excel(r'attachment_2.xlsx', sheet_name = 'system_access', header=0)
#Views
#Employee
employee.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-49ee7121c139> in <module>
#       2 import pandas as pd
#       3 #reading the csv files
# ----> 4 employee = pd.read_excel(r'attachment_1.xlsx', sheet_name = 'employees', header=0)
#       5 sys_access = pd.read_excel(r'attachment_2.xlsx', sheet_name = 'system_access', header=0)
#       6 #Views
#
# F:\xx\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...
